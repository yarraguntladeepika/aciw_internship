# %%
import pandas as pd
data = pd.read_excel(r"C:\Users\Mounika\OneDrive\Desktop\aict intership\Book1.xlsx")
data
# Out:
#    1
# 0  2
# 1  3
# 2  4
# 3  5

# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\Mounika\Downloads\archive.zip")
print(data)
# Out:
#             id             timestamp                       platform  \
# 0            1  2014-07-13T23:56:17Z  WebPlayer (websocket RFC6455)
# 1            2  2014-07-13T23:56:28Z  WebPlayer (websocket RFC6455)
# 2            3  2014-07-13T23:56:32Z  WebPlayer (websocket RFC6455)
# 3            4  2014-07-13T23:59:00Z  WebPlayer (websocket RFC6455)
# 4            5  2014-07-13T23:59:06Z  WebPlayer (websocket RFC6455)
# ...        ...                   ...                            ...
# 106128  106129  2025-08-03T23:06:15Z                        android
# 106129  106130  2025-08-03T23:09:13Z                        android
# 106130  106131  2025-08-03T23:11:57Z                        android
# 106131  106132  2025-08-03T23:14:56Z                        android
# 106132  106133  2025-08-03T23:17:49Z                        android
#
#         duration_ms          track_name             artist  \
# 0                 0        Did It Hurt?  Never Shout Never
# ...

# %%
data.size
# Out:
# 1379729

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106133 entries, 0 to 106132
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            106133 non-null  int64
#  1   timestamp     106133 non-null  object
#  2   platform      106133 non-null  object
#  3   duration_ms   106133 non-null  int64
#  4   track_name    106060 non-null  object
#  5   artist        106060 non-null  object
#  6   album         106017 non-null  object
#  7   track_uri     106060 non-null  object
#  8   reason_start  106131 non-null  object
#  9   reason_end    106132 non-null  object
#  10  shuffle       106133 non-null  int64
#  11  skipped       106133 non-null  int64
#  12  source_file   106133 non-null  object
# dtypes: int64(4), object(9)
# memory usage: 10.5+ MB

# %%
data.describe()
# Out:
#                   id   duration_ms        shuffle        skipped
# count  106133.000000  1.061330e+05  106133.000000  106133.000000
# mean    53067.000000  1.266935e+05       0.171125       0.109335
# std     30638.102397  1.040743e+05       0.376620       0.312060
# min         1.000000  0.000000e+00       0.000000       0.000000
# 25%     26534.000000  1.730300e+04       0.000000       0.000000
# 50%     53067.000000  1.469460e+05       0.000000       0.000000
# 75%     79600.000000  2.025370e+05       0.000000       0.000000
# max    106133.000000  4.185373e+06       1.000000       1.000000

# %%
data.isnull().sum
# Out:
# <bound method DataFrame.sum of            id  timestamp  platform  duration_ms  track_name  artist  album  \
# 0       False      False     False        False       False   False  False
# 1       False      False     False        False       False   False  False
# 2       False      False     False        False       False   False  False
# 3       False      False     False        False       False   False  False
# 4       False      False     False        False       False   False  False
# ...       ...        ...       ...          ...         ...     ...    ...
# 106128  False      False     False        False       False   False  False
# 106129  False      False     False        False       False   False  False
# 106130  False      False     False        False       False   False  False
# 106131  False      False     False        False       False   False  False
# 106132  False      False     False        False       False   False  False
#
# ...

# %%
data_cleaned = data.dropna()

# %%
data_cleaned.columns
# Out:
# Index(['id', 'timestamp', 'platform', 'duration_ms', 'track_name', 'artist',
#        'album', 'track_uri', 'reason_start', 'reason_end', 'shuffle',
#        'skipped', 'source_file'],
#       dtype='object')

# %%
data.shape
# Out:
# (106133, 13)

# %%
data_cleaned.size
# Out:
# 1378182

# %%
data.head(20)
# Out:
#     id             timestamp                       platform  duration_ms  \
# 0    1  2014-07-13T23:56:17Z  WebPlayer (websocket RFC6455)            0
# 1    2  2014-07-13T23:56:28Z  WebPlayer (websocket RFC6455)            0
# 2    3  2014-07-13T23:56:32Z  WebPlayer (websocket RFC6455)         2413
# 3    4  2014-07-13T23:59:00Z  WebPlayer (websocket RFC6455)       145893
# 4    5  2014-07-13T23:59:06Z  WebPlayer (websocket RFC6455)         4430
# 5    6  2014-07-14T00:02:09Z  WebPlayer (websocket RFC6455)       176268
# 6    7  2014-07-14T00:05:58Z  WebPlayer (websocket RFC6455)            0
# 7    8  2014-07-14T00:09:48Z  WebPlayer (websocket RFC6455)            0
# 8    9  2014-07-14T00:10:36Z  WebPlayer (websocket RFC6455)        44447
# 9   10  2014-07-14T00:13:30Z  WebPlayer (websocket RFC6455)       172519
# 10  11  2014-07-14T00:16:37Z  WebPlayer (websocket RFC6455)       169873
# 11  12  2014-07-14T00:17:03Z  WebPlayer (websocket RFC6455)        25255
# ...

# %%
data_cleaned.size
# Out:
# 1378182

# %%
data_cleaned.shape
# Out:
# (106014, 13)

# %%
data_cleaned.head(20)
# Out:
#     id             timestamp                       platform  duration_ms  \
# 0    1  2014-07-13T23:56:17Z  WebPlayer (websocket RFC6455)            0
# 1    2  2014-07-13T23:56:28Z  WebPlayer (websocket RFC6455)            0
# 2    3  2014-07-13T23:56:32Z  WebPlayer (websocket RFC6455)         2413
# 3    4  2014-07-13T23:59:00Z  WebPlayer (websocket RFC6455)       145893
# 4    5  2014-07-13T23:59:06Z  WebPlayer (websocket RFC6455)         4430
# 5    6  2014-07-14T00:02:09Z  WebPlayer (websocket RFC6455)       176268
# 6    7  2014-07-14T00:05:58Z  WebPlayer (websocket RFC6455)            0
# 7    8  2014-07-14T00:09:48Z  WebPlayer (websocket RFC6455)            0
# 8    9  2014-07-14T00:10:36Z  WebPlayer (websocket RFC6455)        44447
# 9   10  2014-07-14T00:13:30Z  WebPlayer (websocket RFC6455)       172519
# 10  11  2014-07-14T00:16:37Z  WebPlayer (websocket RFC6455)       169873
# 11  12  2014-07-14T00:17:03Z  WebPlayer (websocket RFC6455)        25255
# ...

# %%
data.reset_index()
# Out:
#          index      id             timestamp                       platform  \
# 0            0       1  2014-07-13T23:56:17Z  WebPlayer (websocket RFC6455)
# 1            1       2  2014-07-13T23:56:28Z  WebPlayer (websocket RFC6455)
# 2            2       3  2014-07-13T23:56:32Z  WebPlayer (websocket RFC6455)
# 3            3       4  2014-07-13T23:59:00Z  WebPlayer (websocket RFC6455)
# 4            4       5  2014-07-13T23:59:06Z  WebPlayer (websocket RFC6455)
# ...        ...     ...                   ...                            ...
# 106128  106128  106129  2025-08-03T23:06:15Z                        android
# 106129  106129  106130  2025-08-03T23:09:13Z                        android
# 106130  106130  106131  2025-08-03T23:11:57Z                        android
# 106131  106131  106132  2025-08-03T23:14:56Z                        android
# 106132  106132  106133  2025-08-03T23:17:49Z                        android
#
# ...

# %%
data_cleaned.columns
# Out:
# Index(['id', 'timestamp', 'platform', 'duration_ms', 'track_name', 'artist',
#        'album', 'track_uri', 'reason_start', 'reason_end', 'shuffle',
#        'skipped', 'source_file'],
#       dtype='object')

# %%
data_nonul = data.dropna

# %%
data.size
# Out:
# 1379729

# %%
data.head(20)
# Out:
#     id             timestamp                       platform  duration_ms  \
# 0    1  2014-07-13T23:56:17Z  WebPlayer (websocket RFC6455)            0
# 1    2  2014-07-13T23:56:28Z  WebPlayer (websocket RFC6455)            0
# 2    3  2014-07-13T23:56:32Z  WebPlayer (websocket RFC6455)         2413
# 3    4  2014-07-13T23:59:00Z  WebPlayer (websocket RFC6455)       145893
# 4    5  2014-07-13T23:59:06Z  WebPlayer (websocket RFC6455)         4430
# 5    6  2014-07-14T00:02:09Z  WebPlayer (websocket RFC6455)       176268
# 6    7  2014-07-14T00:05:58Z  WebPlayer (websocket RFC6455)            0
# 7    8  2014-07-14T00:09:48Z  WebPlayer (websocket RFC6455)            0
# 8    9  2014-07-14T00:10:36Z  WebPlayer (websocket RFC6455)        44447
# 9   10  2014-07-14T00:13:30Z  WebPlayer (websocket RFC6455)       172519
# 10  11  2014-07-14T00:16:37Z  WebPlayer (websocket RFC6455)       169873
# 11  12  2014-07-14T00:17:03Z  WebPlayer (websocket RFC6455)        25255
# ...

# %%
data_nonull
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 data_nonull
#
# NameError: name 'data_nonull' is not defined

# %%
import matplotlib.pyplot as plt

# %%
data_nonull

# %%
data.dropna(inplace=True)

# %%
data.reset_index(inplace=True,level=0)

# %%
data.drop(columns='index')

# %%
data.duplicated().sum()

# %%
data.drop_duplicates()

# %%
data.columns

# %%
data_numerical_coll = ['id', 'timestamp', 'platform', 'duration_ms', 'track_name',
       'artist', 'album', 'track_uri', 'reason_start', 'reason_end', 'shuffle',
       'skipped', 'source_file']

# %%
import matplotlib.pyplot as plt

# %%
X = data['id']
Y = data['duration_ms']
plt.scatter(x = X , y = Y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
X = data['id']
Y = data['duration_ms']
plt.scatter(x=X,y=Y,cmap='red')
plt.title("id vs duration_ms")
plt.xlabel("id")
plt.ylabel("duration_ms")
plt.grid()
plt.show
# Out:
# C:\Users\Mounika\AppData\Local\Temp\ipykernel_1968\2789788517.py:3: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x=X,y=Y,cmap='red')
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
X = data['id']
Y = data['duration_ms']
plt.scatter(x=X,y=Y,marker='*',cmap='plasma',c='green')
plt.title("id vs duration_ms")
plt.xlabel("id")
plt.ylabel("duration_ms")
plt.grid()
plt.show
# Out:
# C:\Users\Mounika\AppData\Local\Temp\ipykernel_1968\2556440310.py:3: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x=X,y=Y,marker='*',cmap='plasma',c='green')
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(X,width=2,height=20000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 plt.bar(X,width=2,height=20000)
#
# File c:\Users\Mounika\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:2989, in bar(x, height, width, bottom, align, data, **kwargs)
#    2978 @_copy_docstring_and_deprecators(Axes.bar)
#    2979 def bar(
#    2980     x: float | ArrayLike,
#    (...)   2987     **kwargs,
#    2988 ) -> BarContainer:
# -> 2989     return gca().bar(
#    2990         x,
#    2991         height,
#    2992         width=width,
#    2993         bottom=bottom,
#    2994         align=align,
#    2995         **({"data": data} if data is not None else {}),
#    2996         **kwargs,
#    2997     )
#
# ...

# %%
plt.boxplot(X)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1402c1e4ad0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1402c1e4d70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1402c1e4980>],
#  'medians': [<matplotlib.lines.Line2D at 0x1402c1e5010>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1402c1e5160>],
#  'means': []}

# %%
plt.hist(X,bins=50,range=(0,100000))
# Out:
# (array([1999., 2000., 2000., 2000., 2000., 2000., 2000., 2000., 2000.,
#         2000., 2000., 2000., 2000., 2000., 2000., 2000., 2000., 2000.,
#         2000., 2000., 2000., 2000., 2000., 2000., 2000., 2000., 2000.,
#         2000., 2000., 2000., 2000., 2000., 2000., 2000., 2000., 2000.,
#         2000., 2000., 2000., 2000., 2000., 2000., 2000., 2000., 2000.,
#         2000., 2000., 2000., 2000., 2001.]),
#  array([     0.,   2000.,   4000.,   6000.,   8000.,  10000.,  12000.,
#          14000.,  16000.,  18000.,  20000.,  22000.,  24000.,  26000.,
#          28000.,  30000.,  32000.,  34000.,  36000.,  38000.,  40000.,
#          42000.,  44000.,  46000.,  48000.,  50000.,  52000.,  54000.,
#          56000.,  58000.,  60000.,  62000.,  64000.,  66000.,  68000.,
#          70000.,  72000.,  74000.,  76000.,  78000.,  80000.,  82000.,
#          84000.,  86000.,  88000.,  90000.,  92000.,  94000.,  96000.,
#          98000., 100000.]),
#  <BarContainer object of 50 artists>)

# %%
plt.pie(X)
# Out:
# ([<matplotlib.patches.Wedge at 0x1402bff4ec0>,
# ...
#   ...],
#  [Text(1.1, 6.135749019975379e-10, ''),
#   Text(1.1, 2.4542996079901515e-09, ''),
#   Text(1.1, 5.5221743622269064e-09, ''),
#   Text(1.1, 9.817198431960606e-09, ''),
#   Text(1.0999999999999999, 1.5339373771183773e-08, ''),
#   Text(1.0999999999999999, 2.2088697448907626e-08, ''),
#   Text(1.0999999999999996, 3.006517044212842e-08, ''),
#   Text(1.0999999999999994, 3.926879372784242e-08, ''),
#   Text(1.099999999999999, 4.9699569260042146e-08, ''),
#   Text(1.0999999999999983, 6.135748726876497e-08, ''),
#   Text(1.0999999999999974, 7.424256338595109e-08, ''),
#   Text(1.0999999999999965, 8.83547897956304e-08, ''),
#   Text(1.0999999999999952, 1.0369416258981786e-07, ''),
#   Text(1.0999999999999934, 1.2026069740045365e-07, ''),
#   Text(1.0999999999999914, 1.3805435514768725e-07, ''),
#   Text(1.0999999999999888, 1.5707517491136917e-07, ''),
#   Text(1.0999999999999859, 1.773231488755293e-07, ''),
# ...

# %%
plt.pie(X,radius=6)
# Out:
# ([<matplotlib.patches.Wedge at 0x140e7df16d0>,
# ...
#   ...],
#  [Text(6.6000000000000005, 3.6814494119852273e-09, ''),
#   Text(6.6000000000000005, 1.4725797647940909e-08, ''),
#   Text(6.6000000000000005, 3.313304617336144e-08, ''),
#   Text(6.6000000000000005, 5.8903190591763636e-08, ''),
#   Text(6.6, 9.203624262710265e-08, ''),
#   Text(6.599999999999999, 1.3253218469344575e-07, ''),
#   Text(6.599999999999999, 1.803910226527705e-07, ''),
#   Text(6.599999999999996, 2.356127623670545e-07, ''),
#   Text(6.599999999999994, 2.9819741556025285e-07, ''),
#   Text(6.59999999999999, 3.681449236125898e-07, ''),
#   Text(6.599999999999985, 4.4545538031570653e-07, ''),
#   Text(6.599999999999979, 5.301287387737824e-07, ''),
#   Text(6.599999999999971, 6.221649755389071e-07, ''),
#   Text(6.599999999999961, 7.215641844027218e-07, ''),
#   Text(6.599999999999948, 8.283261308861236e-07, ''),
#   Text(6.599999999999933, 9.42451049468215e-07, ''),
# ...
